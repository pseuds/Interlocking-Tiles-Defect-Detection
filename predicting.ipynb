# %%
from ultralytics import YOLO

# %%
model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a model
model = YOLO(model_path)  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(source=[
    'datasets_sorted/PunggolMeridian_MRT/IMG_0008.JPG', 
    'datasets_sorted/PunggolMeridian_MRT/IMG_0019.JPG', 
    ],
    conf=0.8, iou=0.5, imgsz=800
    )  # return a list of Results objects
# Out:
# 0: 608x800 2 interlocking-tiless, 1 road marking -good-, 1: 608x800 1 interlocking-tiles, 646.6ms
# Speed: 8.2ms preprocess, 323.3ms inference, 10.7ms postprocess per image at shape (1, 3, 608, 800)

# %%
from PIL import Image
import numpy as np
import cv2

# Process results list
for result in results:
    print(result.names)
    cls = result.boxes.cls  # Boxes object for bbox outputs
    conf = result.boxes.conf  # Boxes object for bbox outputs
    print(cls, conf)

    sorted_cls, sorted_conf = [], []
    for label, confidence in zip(cls, conf):
        print(int(label), float(confidence))
        if confidence > 0.5:
            sorted_cls.append(label)
            sorted_conf.append(confidence)

    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

    array = result.plot()
    array = array[:, :, ::-1]
    img = Image.fromarray(array)
    img.show()

    # print(array)
# Out:
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([1., 1., 5.]) tensor([0.9498, 0.9428, 0.8851])
# 1 0.9497528076171875
# 1 0.9427695870399475
# 5 0.885108232498169
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([1.]) tensor([0.9162])
# 1 0.9161919951438904

# %% [markdown]
# <a href="https://docs.ultralytics.com/modes/predict/#inference-arguments">Inference Arguments</a>

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a pretrained YOLOv8n model
model = YOLO(model_path)
# Everton, Punggol_blk160_166, Punggol_EdgeField_BLK105, Punggol_EdgeField_BLK111, PunggolMeridian_MRT, TiongBahru
image_path = "output/test/IMG_0019.JPG"
image_paths = [
    "datasets_sorted/PunggolMeridian_MRT/IMG_0008.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0021.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0025.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0035.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0041.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_9994.JPG",
    "datasets_sorted/TiongBahru/IMG_8823.JPG",
    "datasets_sorted/TiongBahru/IMG_8883.JPG",
    "datasets_sorted/TiongBahru/IMG_8884.JPG",
    "datasets_sorted/TiongBahru/IMG_8885.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8926.JPG",
    "datasets_sorted/TiongBahru/IMG_8997.JPG",
    "datasets_sorted/TiongBahru/IMG_9012.JPG",
    "datasets_sorted/TiongBahru/IMG_9015.JPG",
]
video_path = "output/videos/GH012496_processed.mp4"

# Run inference on 'bus.jpg' with arguments
model.predict(video_path, save=True, imgsz=800, conf=0.5)

# %% [markdown]
# ### Model Track

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a pretrained YOLOv8n model
model = YOLO(model_path)
# Everton, Punggol_blk160_166, Punggol_EdgeField_BLK105, Punggol_EdgeField_BLK111, PunggolMeridian_MRT, TiongBahru
image_path = "output/test/IMG_0019.JPG"
image_paths = [
    "datasets_sorted/PunggolMeridian_MRT/IMG_0008.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0021.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0025.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0035.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0041.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_9994.JPG",
    "datasets_sorted/TiongBahru/IMG_8823.JPG",
    "datasets_sorted/TiongBahru/IMG_8883.JPG",
    "datasets_sorted/TiongBahru/IMG_8884.JPG",
    "datasets_sorted/TiongBahru/IMG_8885.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8926.JPG",
    "datasets_sorted/TiongBahru/IMG_8997.JPG",
    "datasets_sorted/TiongBahru/IMG_9012.JPG",
    "datasets_sorted/TiongBahru/IMG_9015.JPG",
]
video_path = "output/videos/GH012496_processed.mp4"

# Run inference on 'bus.jpg' with arguments
results = model.track(source=video_path, conf=0.3, iou=0.5, show=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 675.4ms
# video 1/1 (2/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 622.0ms
# video 1/1 (3/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 632.4ms
# video 1/1 (4/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 607.3ms
# video 1/1 (5/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 662.8ms
# video 1/1 (6/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 640.2ms
# video 1/1 (7/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 563.6ms
# video 1/1 (8/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 672.9ms
# video 1/1 (9/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 654.2ms
# video 1/1 (10/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 619.6ms
# video 1/1 (11/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 607.2ms
# video 1/1 (12/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 585.9ms
# video 1/1 (13/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 720.1ms
# video 1/1 (14/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 694.8ms
# video 1/1 (15/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 647.5ms
# video 1/1 (16/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 620.7ms
# video 1/1 (17/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 588.5ms
# video 1/1 (18/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 639.3ms
# video 1/1 (19/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 609.9ms
# video 1/1 (20/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 586.2ms
# video 1/1 (21/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 655.1ms
# video 1/1 (22/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 587.1ms
# video 1/1 (23/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 607.5ms
# video 1/1 (24/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 629.8ms
# video 1/1 (25/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 591.7ms
# video 1/1 (26/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 667.3ms
# video 1/1 (27/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 587.6ms
# video 1/1 (28/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 621.0ms
# video 1/1 (29/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 665.9ms
# video 1/1 (30/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 636.5ms
# video 1/1 (31/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 613.3ms
# video 1/1 (32/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 694.6ms
# video 1/1 (33/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 606.1ms
# video 1/1 (34/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 635.3ms
# video 1/1 (35/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 611.6ms
# video 1/1 (36/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 669.4ms
# video 1/1 (37/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 628.8ms
# video 1/1 (38/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 611.9ms
# video 1/1 (39/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 632.3ms
# video 1/1 (40/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 611.2ms
# video 1/1 (41/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 612.9ms
# video 1/1 (42/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 667.8ms
# video 1/1 (43/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 584.2ms
# video 1/1 (44/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 661.7ms
# video 1/1 (45/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 618.9ms
# video 1/1 (46/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 610.0ms
# video 1/1 (47/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 658.4ms
# video 1/1 (48/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 610.3ms
# video 1/1 (49/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 666.2ms
# video 1/1 (50/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 606.3ms
# video 1/1 (51/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 647.1ms
# video 1/1 (52/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 648.1ms
# video 1/1 (53/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 2 road marking -good-s, 608.6ms
# video 1/1 (54/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 642.3ms
# video 1/1 (55/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 634.5ms
# video 1/1 (56/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 648.0ms
# video 1/1 (57/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 648.8ms
# video 1/1 (58/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 586.1ms
# video 1/1 (59/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 627.7ms
# video 1/1 (60/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 606.6ms
# video 1/1 (61/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 604.6ms
# video 1/1 (62/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 647.2ms
# video 1/1 (63/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 638.3ms
# video 1/1 (64/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 603.6ms
# video 1/1 (65/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 657.0ms
# video 1/1 (66/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 582.3ms
# video 1/1 (67/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 620.3ms
# video 1/1 (68/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 668.6ms
# video 1/1 (69/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 653.6ms
# video 1/1 (70/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 670.6ms
# video 1/1 (71/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 548.1ms
# video 1/1 (72/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 605.1ms
# video 1/1 (73/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 644.9ms
# video 1/1 (74/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 648.1ms
# video 1/1 (75/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 704.6ms
# video 1/1 (76/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 587.9ms
# video 1/1 (77/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 594.6ms
# video 1/1 (78/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 684.6ms
# video 1/1 (79/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 567.6ms
# video 1/1 (80/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 617.1ms
# video 1/1 (81/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 589.1ms
# video 1/1 (82/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 633.1ms
# video 1/1 (83/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 662.7ms
# video 1/1 (84/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 581.0ms
# video 1/1 (85/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 591.8ms
# video 1/1 (86/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 624.1ms
# video 1/1 (87/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 634.3ms
# video 1/1 (88/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 652.0ms
# video 1/1 (89/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 590.6ms
# video 1/1 (90/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 621.6ms
# video 1/1 (91/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 665.6ms
# video 1/1 (92/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 591.0ms
# video 1/1 (93/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 612.6ms
# video 1/1 (94/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 583.1ms
# video 1/1 (95/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 620.2ms
# video 1/1 (96/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 658.8ms
# video 1/1 (97/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 596.7ms
# video 1/1 (98/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 568.3ms
# video 1/1 (99/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 650.4ms
# video 1/1 (100/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 597.2ms
# video 1/1 (101/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 592.5ms
# video 1/1 (102/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 582.9ms
# video 1/1 (103/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 602.1ms
# video 1/1 (104/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 668.2ms
# video 1/1 (105/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 655.7ms
# video 1/1 (106/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 616.9ms
# video 1/1 (107/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 662.6ms
# video 1/1 (108/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 569.6ms
# video 1/1 (109/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 672.2ms
# video 1/1 (110/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 568.5ms
# video 1/1 (111/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 580.1ms
# video 1/1 (112/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 623.0ms
# video 1/1 (113/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 613.7ms
# video 1/1 (114/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 615.7ms
# video 1/1 (115/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 600.4ms
# video 1/1 (116/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 602.7ms
# video 1/1 (117/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 660.8ms
# video 1/1 (118/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 554.9ms
# video 1/1 (119/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 565.2ms
# video 1/1 (120/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 638.7ms
# video 1/1 (121/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 653.4ms
# video 1/1 (122/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 665.1ms
# video 1/1 (123/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 628.4ms
# video 1/1 (124/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 580.6ms
# video 1/1 (125/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 668.2ms
# video 1/1 (126/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 604.5ms
# video 1/1 (127/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 612.6ms
# video 1/1 (128/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 625.8ms
# video 1/1 (129/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 611.0ms
# video 1/1 (130/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 656.7ms
# video 1/1 (131/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 542.1ms
# video 1/1 (132/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 607.7ms
# video 1/1 (133/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 657.4ms
# video 1/1 (134/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 652.6ms
# video 1/1 (135/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 588.6ms
# video 1/1 (136/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 632.8ms
# video 1/1 (137/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 610.2ms
# video 1/1 (138/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 623.0ms
# video 1/1 (139/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 574.9ms
# video 1/1 (140/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 555.0ms
# video 1/1 (141/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 645.7ms
# video 1/1 (142/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 601.8ms
# video 1/1 (143/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 585.1ms
# video 1/1 (144/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 721.1ms
# video 1/1 (145/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 603.4ms
# video 1/1 (146/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 621.2ms
# video 1/1 (147/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 568.8ms
# video 1/1 (148/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 571.1ms
# video 1/1 (149/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 635.9ms
# video 1/1 (150/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 627.7ms
# video 1/1 (151/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 522.8ms
# video 1/1 (152/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 622.6ms
# video 1/1 (153/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 575.0ms
# video 1/1 (154/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 654.7ms
# video 1/1 (155/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 646.0ms
# video 1/1 (156/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 576.1ms
# video 1/1 (157/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 670.0ms
# video 1/1 (158/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 629.4ms
# video 1/1 (159/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 576.6ms
# video 1/1 (160/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 663.1ms
# video 1/1 (161/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 598.5ms
# video 1/1 (162/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 619.8ms
# video 1/1 (163/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 562.8ms
# video 1/1 (164/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 597.1ms
# video 1/1 (165/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 634.8ms
# video 1/1 (166/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 589.7ms
# video 1/1 (167/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 549.6ms
# video 1/1 (168/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 638.8ms
# video 1/1 (169/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 605.3ms
# video 1/1 (170/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 546.0ms
# video 1/1 (171/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 626.4ms
# video 1/1 (172/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 588.4ms
# video 1/1 (173/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 600.0ms
# video 1/1 (174/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 631.4ms
# video 1/1 (175/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 585.1ms
# video 1/1 (176/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 645.2ms
# video 1/1 (177/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 572.8ms
# video 1/1 (178/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 549.0ms
# video 1/1 (179/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 656.5ms
# video 1/1 (180/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 624.6ms
# video 1/1 (181/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 570.8ms
# video 1/1 (182/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 628.3ms
# video 1/1 (183/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 656.3ms
# video 1/1 (184/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 617.7ms
# video 1/1 (185/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 580.0ms
# video 1/1 (186/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 563.6ms
# video 1/1 (187/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 638.1ms
# video 1/1 (188/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 605.1ms
# video 1/1 (189/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 581.3ms
# video 1/1 (190/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 666.2ms
# video 1/1 (191/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 602.9ms
# video 1/1 (192/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 531.7ms
# video 1/1 (193/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 641.9ms
# video 1/1 (194/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 602.4ms
# video 1/1 (195/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 629.2ms
# video 1/1 (196/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 610.4ms
# video 1/1 (197/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 588.4ms
# video 1/1 (198/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 634.0ms
# video 1/1 (199/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 691.1ms
# video 1/1 (200/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 640.3ms
# video 1/1 (201/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 702.6ms
# video 1/1 (202/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 678.3ms
# video 1/1 (203/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 725.4ms
# video 1/1 (204/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 677.7ms
# video 1/1 (205/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 603.1ms
# video 1/1 (206/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 624.9ms
# video 1/1 (207/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 625.9ms
# video 1/1 (208/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 630.2ms
# video 1/1 (209/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 618.7ms
# video 1/1 (210/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 567.6ms
# video 1/1 (211/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 656.6ms
# video 1/1 (212/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 622.5ms
# video 1/1 (213/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 578.8ms
# video 1/1 (214/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 635.1ms
# video 1/1 (215/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 582.6ms
# video 1/1 (216/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 604.7ms
# video 1/1 (217/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 630.1ms
# video 1/1 (218/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 595.1ms
# video 1/1 (219/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 641.6ms
# video 1/1 (220/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 641.6ms
# video 1/1 (221/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 538.2ms
# video 1/1 (222/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 668.1ms
# video 1/1 (223/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 659.1ms
# video 1/1 (224/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 615.7ms
# video 1/1 (225/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 596.1ms
# video 1/1 (226/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 640.1ms
# video 1/1 (227/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 639.6ms
# video 1/1 (228/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 650.1ms
# video 1/1 (229/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 572.5ms
# video 1/1 (230/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 625.1ms
# video 1/1 (231/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 637.1ms
# video 1/1 (232/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 583.1ms
# video 1/1 (233/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 642.1ms
# video 1/1 (234/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 613.0ms
# video 1/1 (235/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 613.6ms
# video 1/1 (236/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 652.1ms
# video 1/1 (237/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 629.1ms
# video 1/1 (238/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 604.1ms
# video 1/1 (239/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 622.6ms
# video 1/1 (240/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 571.6ms
# video 1/1 (241/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 624.7ms
# video 1/1 (242/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 631.5ms
# video 1/1 (243/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 583.6ms
# video 1/1 (244/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 645.1ms
# video 1/1 (245/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 603.1ms
# video 1/1 (246/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 609.4ms
# video 1/1 (247/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 604.7ms
# video 1/1 (248/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 573.1ms
# video 1/1 (249/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 600.1ms
# video 1/1 (250/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 654.4ms
# video 1/1 (251/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 612.1ms
# video 1/1 (252/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 589.1ms
# video 1/1 (253/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 648.6ms
# video 1/1 (254/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 598.1ms
# video 1/1 (255/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 555.1ms
# video 1/1 (256/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 614.1ms
# video 1/1 (257/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 577.6ms
# video 1/1 (258/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 614.1ms
# video 1/1 (259/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 747.6ms
# video 1/1 (260/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 651.2ms
# video 1/1 (261/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 620.1ms
# video 1/1 (262/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 618.1ms
# video 1/1 (263/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 595.1ms
# video 1/1 (264/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 616.5ms
# video 1/1 (265/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 561.1ms
# video 1/1 (266/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 643.1ms
# video 1/1 (267/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 624.1ms
# video 1/1 (268/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 567.1ms
# video 1/1 (269/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 665.6ms
# video 1/1 (270/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 603.1ms
# video 1/1 (271/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 578.6ms
# video 1/1 (272/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 620.1ms
# video 1/1 (273/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 601.1ms
# video 1/1 (274/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 613.1ms
# video 1/1 (275/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 625.6ms
# video 1/1 (276/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 611.1ms
# video 1/1 (277/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 876.7ms
# video 1/1 (278/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 620.1ms
# video 1/1 (279/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 580.1ms
# video 1/1 (280/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 664.6ms
# video 1/1 (281/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 567.1ms
# video 1/1 (282/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 675.8ms
# video 1/1 (283/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 612.1ms
# video 1/1 (284/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 582.0ms
# video 1/1 (285/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 632.1ms
# video 1/1 (286/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 602.1ms
# video 1/1 (287/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 588.1ms
# video 1/1 (288/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 696.5ms
# video 1/1 (289/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 686.2ms
# video 1/1 (290/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 586.9ms
# video 1/1 (291/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 648.1ms
# video 1/1 (292/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 561.6ms
# video 1/1 (293/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 586.1ms
# video 1/1 (294/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 608.1ms
# Speed: 6.0ms preprocess, 620.4ms inference, 18.8ms postprocess per image at shape (1, 3, 800, 800)

# %%
from PIL import Image
import numpy as np
import cv2
from cv_functions import count_to_string

output_folder = "output/test_track"

count = 0
# Process results list
for result in results:
    print(result.names)
    boxes = result.boxes.cls  # Boxes object for bbox outputs
    boxes = result.boxes.conf  # Boxes object for bbox outputs
    print(boxes)
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

    array = result.plot()
    array = array[:,:, ::-1]
    img = Image.fromarray(array)
    # img.show()

    img.save(f"{output_folder}/frame{count_to_string(count)}.jpg")

    count += 1


    # print(array)
# Out:
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8756, 0.8598, 0.7915, 0.7204])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8288, 0.8709, 0.8195, 0.8356])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8215, 0.8666, 0.8117, 0.8322, 0.5228])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8135, 0.8769, 0.7843, 0.8249, 0.6447])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8233, 0.8473, 0.7671, 0.8568, 0.6183])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7734, 0.8511, 0.7305, 0.8532, 0.5850])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7439, 0.8453, 0.8109, 0.8405, 0.5675])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8097, 0.8516, 0.8368, 0.7797, 0.6193])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7383, 0.8569, 0.8469, 0.8184, 0.6257])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8320, 0.8476, 0.8563, 0.8513, 0.6686])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8371, 0.8263, 0.8110, 0.8343, 0.6390])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8026, 0.8363, 0.8112, 0.8793, 0.6753])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5077, 0.8240, 0.8229, 0.8144, 0.6794])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7300, 0.8398, 0.7265, 0.8577, 0.6422, 0.5483])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7695, 0.8065, 0.8088, 0.8028, 0.5598, 0.5157])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6435, 0.8409, 0.7042, 0.8502, 0.7526, 0.3528])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7041, 0.8109, 0.6778, 0.8745, 0.8299, 0.3930])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4902, 0.7508, 0.7188, 0.9105, 0.8155, 0.4856])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5400, 0.8105, 0.6711, 0.8966, 0.8113, 0.3939])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6293, 0.7682, 0.6082, 0.8434, 0.8221, 0.6664])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5311, 0.7973, 0.7196, 0.8710, 0.7983, 0.5907])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5951, 0.7515, 0.6507, 0.8676, 0.7760, 0.6541])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3414, 0.8091, 0.7905, 0.8872, 0.7214, 0.7356])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4445, 0.7881, 0.8191, 0.8721, 0.5508, 0.7356])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3033, 0.8279, 0.8443, 0.9112, 0.5133, 0.7913])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3574, 0.8320, 0.8354, 0.8615, 0.6888, 0.6896])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3794, 0.8618, 0.8072, 0.8852, 0.6055, 0.7152])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4321, 0.8778, 0.8330, 0.8397, 0.7126, 0.7241])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5578, 0.8776, 0.8050, 0.7692, 0.5552, 0.7913])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4926, 0.8656, 0.7876, 0.7352, 0.6061, 0.7335])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5595, 0.8956, 0.7071, 0.4510, 0.5791, 0.7426])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6154, 0.8855, 0.5680, 0.3685, 0.5785, 0.6967])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4699, 0.8738, 0.7368, 0.3553, 0.6507, 0.8282])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4204, 0.8902, 0.6402, 0.7140, 0.8022])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5002, 0.8655, 0.5383, 0.6517, 0.7643])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8793, 0.7292, 0.7136, 0.8308])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8973, 0.6498, 0.7197, 0.8534])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8868, 0.7399, 0.7008, 0.8035, 0.6201])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8964, 0.7968, 0.6852, 0.7961, 0.6131])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8963, 0.8594, 0.7372, 0.8626, 0.5469])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9000, 0.8200, 0.6123, 0.8310, 0.6456])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8808, 0.8123, 0.6652, 0.8478, 0.7515])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8831, 0.8000, 0.7137, 0.9081, 0.6184])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8896, 0.6652, 0.5780, 0.8710, 0.5726, 0.5579])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8799, 0.7433, 0.3724, 0.8321, 0.5604, 0.7095])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8752, 0.7478, 0.4221, 0.7531, 0.6512])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8885, 0.8474, 0.3923, 0.7930, 0.6423])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8353, 0.8272, 0.6167, 0.7692, 0.4576, 0.8267])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8376, 0.8151, 0.5715, 0.7390, 0.7027])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8052, 0.7417, 0.6170, 0.5708, 0.8883])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8357, 0.4473, 0.6157, 0.6151, 0.8474, 0.5951])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8640, 0.5904, 0.5491, 0.6048, 0.8704, 0.5636])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8599, 0.7485, 0.5812, 0.5888, 0.8857])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8724, 0.7925, 0.5265, 0.7066, 0.9203])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8614, 0.6372, 0.6677, 0.6964, 0.9323])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8704, 0.8256, 0.6380, 0.6579, 0.8501])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8676, 0.8009, 0.7113, 0.7940, 0.8834])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8157, 0.7369, 0.5815, 0.7550, 0.8429])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8271, 0.5997, 0.7116, 0.8003, 0.9001])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8202, 0.4724, 0.6956, 0.7848, 0.8716])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8111, 0.4815, 0.7549, 0.6025, 0.9086])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8197, 0.6593, 0.6687, 0.5374, 0.8450])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8294, 0.3397, 0.7782, 0.5322, 0.9040])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8333, 0.5157, 0.4965, 0.5729, 0.8797])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8450, 0.7140, 0.7968, 0.4272, 0.9120])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8619, 0.7499, 0.7642, 0.5119, 0.9142])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8595, 0.5670, 0.7880, 0.4526, 0.8983])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8661, 0.6711, 0.7508, 0.6004, 0.9151])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8976, 0.4715, 0.7942, 0.5004, 0.8801, 0.6656])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8992, 0.6489, 0.6597, 0.5163, 0.9109, 0.7153])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8776, 0.4305, 0.7664, 0.5619, 0.9001])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8891, 0.3482, 0.8200, 0.5496, 0.8839])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9114, 0.6618, 0.7015, 0.7094, 0.9044])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8606, 0.6968, 0.7894, 0.6167, 0.8929])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8864, 0.4985, 0.8407, 0.6521, 0.8859])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9162, 0.7905, 0.6843, 0.5739, 0.8974, 0.6796])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8908, 0.6683, 0.7906, 0.6154, 0.8964, 0.5184])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8863, 0.5741, 0.8083, 0.5572, 0.8813, 0.5749])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8963, 0.7590, 0.4870, 0.5456, 0.8850, 0.6069])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9107, 0.6060, 0.3014, 0.4578, 0.8900, 0.5169])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9008, 0.6890, 0.7170, 0.4350, 0.8946])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9037, 0.5991, 0.7150, 0.5423, 0.8882])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9041, 0.6131, 0.7222, 0.5721, 0.8978])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8983, 0.4664, 0.7364, 0.5338, 0.8886])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8885, 0.6747, 0.6779, 0.6089, 0.8945])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8783, 0.6437, 0.7424, 0.6111, 0.8921])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8966, 0.6958, 0.8519, 0.6228, 0.8856])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9077, 0.7278, 0.7564, 0.5975, 0.9050])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8939, 0.3248, 0.7553, 0.6013, 0.8936])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9009, 0.3581, 0.6971, 0.5498, 0.8980, 0.5668])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9249, 0.7445, 0.7575, 0.5562, 0.8925, 0.5737])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9276, 0.8287, 0.5853, 0.5643, 0.8601, 0.4312])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9145, 0.8230, 0.8755, 0.6126, 0.8858, 0.3945])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9045, 0.7710, 0.8176, 0.6199, 0.8623, 0.4603])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9166, 0.7676, 0.8420, 0.5608, 0.8886, 0.5838])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8992, 0.8462, 0.8788, 0.4976, 0.9141, 0.4963])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8808, 0.8129, 0.8592, 0.4467, 0.8951, 0.5304])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8364, 0.5885, 0.8504, 0.5450, 0.8734])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8781, 0.6938, 0.7285, 0.5790, 0.8845])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8870, 0.7698, 0.8439, 0.4637, 0.8823])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9008, 0.8213, 0.5803, 0.5168, 0.8814])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9109, 0.6666, 0.8572, 0.3880, 0.8938])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8990, 0.5823, 0.7386, 0.3957, 0.8808, 0.6173])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8976, 0.7779, 0.8500, 0.4947, 0.9020, 0.4744])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8969, 0.7715, 0.8589, 0.4390, 0.8898, 0.8143])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8904, 0.7794, 0.8753, 0.3322, 0.8836, 0.6869])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8827, 0.7831, 0.8350, 0.3101, 0.8607, 0.3346])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8795, 0.7819, 0.8429, 0.3284, 0.8828, 0.5999])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8914, 0.7784, 0.8584, 0.3468, 0.9071, 0.4881])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8791, 0.6938, 0.8557, 0.3077, 0.8952, 0.5277])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8599, 0.7616, 0.7820, 0.3369, 0.8684, 0.6094])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8640, 0.7991, 0.8519, 0.3321, 0.8776, 0.5568])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8622, 0.7718, 0.8635, 0.3261, 0.8445, 0.4962])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8387, 0.8404, 0.8721, 0.4049, 0.8698, 0.4666])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8234, 0.8222, 0.8846, 0.3688, 0.8617])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8341, 0.7227, 0.8896, 0.3731, 0.8746])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8193, 0.7392, 0.8770, 0.3517, 0.8477])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8470, 0.7229, 0.8695, 0.8634])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8433, 0.7522, 0.8591, 0.8577])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8422, 0.7838, 0.8521, 0.8446, 0.6441])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8411, 0.8499, 0.8563, 0.8302, 0.5201])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8382, 0.8698, 0.8299, 0.8151, 0.7045])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8308, 0.8082, 0.8331, 0.7733, 0.6437])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8515, 0.7971, 0.8488, 0.7888, 0.5576])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8594, 0.7878, 0.8044, 0.8303, 0.4372])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8609, 0.8459, 0.8194, 0.8406, 0.3652])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8411, 0.8301, 0.8252, 0.8317])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8388, 0.8783, 0.8227, 0.7441])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8429, 0.8873, 0.7968, 0.5231])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8680, 0.8716, 0.8376, 0.6761])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8584, 0.8724, 0.8349, 0.5351])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8513, 0.8092, 0.8297, 0.6165])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8717, 0.8283, 0.8419, 0.5163])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8988, 0.8067, 0.8602, 0.5893])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8420, 0.8403, 0.8187, 0.6276])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8419, 0.8860, 0.7922, 0.6434])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8550, 0.8841, 0.7695, 0.6695, 0.6438])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8701, 0.8905, 0.6709, 0.8126, 0.7507])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8823, 0.9111, 0.6207, 0.7947, 0.6059])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8780, 0.8043, 0.5466, 0.7531, 0.7104])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8298, 0.8486, 0.8262, 0.7688])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8307, 0.8158, 0.7191, 0.8145, 0.7239])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8444, 0.8432, 0.6432, 0.8669, 0.3069])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8414, 0.8436, 0.6797, 0.8337, 0.3592])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8484, 0.8124, 0.7624, 0.8243, 0.4674])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8476, 0.7237, 0.8222, 0.8006, 0.3599])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8447, 0.7822, 0.7629, 0.8476])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8369, 0.8121, 0.8093, 0.8079])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8286, 0.7495, 0.8461, 0.7437])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8348, 0.8098, 0.8051, 0.7101, 0.5223])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8418, 0.7700, 0.8923, 0.5322, 0.4772])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8397, 0.7560, 0.8979, 0.5011])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8442, 0.7821, 0.8822, 0.5439])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8348, 0.8057, 0.9077, 0.4902])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8439, 0.7812, 0.8680, 0.4653])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8643, 0.7601, 0.8858, 0.4429])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8649, 0.7350, 0.8733, 0.4301])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8775, 0.7452, 0.9131, 0.4359])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8621, 0.7075, 0.9196, 0.4400])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8489, 0.7305, 0.9228, 0.4106])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8345, 0.7674, 0.8942, 0.3803])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8360, 0.7451, 0.9140, 0.3824])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8281, 0.6703, 0.9010, 0.4604])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8144, 0.7165, 0.9098, 0.4173])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8349, 0.7359, 0.8922, 0.4394])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8423, 0.7428, 0.9264, 0.4469])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8539, 0.7606, 0.9278, 0.5613])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8256, 0.7871, 0.9311, 0.4480])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8333, 0.5980, 0.9216, 0.4894])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8339, 0.4333, 0.9079, 0.4245])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8527, 0.3364, 0.9121, 0.4637])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8557, 0.6669, 0.9160, 0.4200])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8714, 0.6727, 0.9124, 0.5072])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8674, 0.6399, 0.8893, 0.4887])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8557, 0.5715, 0.8552, 0.5203])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8656, 0.6711, 0.8774, 0.5495])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8744, 0.7334, 0.8789, 0.5273])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8755, 0.7569, 0.8685, 0.5353])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8610, 0.5163, 0.8371, 0.5352])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8614, 0.5251, 0.8385, 0.5886])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8526, 0.5221, 0.8580, 0.5168])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8698, 0.5684, 0.8549, 0.5626])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8582, 0.5501, 0.8838, 0.5030])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8476, 0.4661, 0.8921, 0.5011])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8503, 0.5835, 0.8927, 0.5250])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8131, 0.7519, 0.8869, 0.5370])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8297, 0.6657, 0.8846, 0.5287])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8324, 0.6973, 0.8621, 0.5126])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8084, 0.6048, 0.8534, 0.5504])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8442, 0.5985, 0.8639, 0.5714])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8149, 0.7975, 0.8806, 0.5434])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8076, 0.7173, 0.8717, 0.5382])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8275, 0.7457, 0.8664, 0.5034])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8320, 0.5548, 0.8651, 0.5654])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8326, 0.5665, 0.8714, 0.5539])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8234, 0.5256, 0.8841, 0.5679])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7904, 0.7423, 0.8657, 0.5825])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7950, 0.7833, 0.8652, 0.5554])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7727, 0.6105, 0.8736, 0.5737])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7690, 0.7186, 0.8788, 0.5881])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7474, 0.7585, 0.8677, 0.6003])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7538, 0.8142, 0.8853, 0.4693])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7310, 0.7223, 0.8707, 0.5109])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7726, 0.6807, 0.8753, 0.4675])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7137, 0.7062, 0.8642, 0.6382])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7844, 0.6539, 0.8671, 0.6103])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7617, 0.6233, 0.8516, 0.5850])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7969, 0.5208, 0.8301, 0.5328])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7786, 0.5488, 0.8331, 0.6104])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8243, 0.5556, 0.8348, 0.5092])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7962, 0.3564, 0.8506, 0.5461])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8259, 0.5768, 0.8583, 0.3134])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7934, 0.5915, 0.8489, 0.3946])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7895, 0.5802, 0.8086, 0.3103])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8027, 0.5647, 0.7801])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7723, 0.5602, 0.7902])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7842, 0.6205, 0.8344])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8039, 0.5777, 0.7868])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7585, 0.5356, 0.8345])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7466, 0.6402, 0.8233])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7336, 0.6669, 0.8394])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7431, 0.6475, 0.8187])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7845, 0.7342, 0.8167])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7721, 0.6689, 0.8239])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7628, 0.6527, 0.8244, 0.6172])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7531, 0.7863, 0.8240, 0.5980])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7766, 0.7636, 0.8365])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7857, 0.7846, 0.8520, 0.7291])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7512, 0.7239, 0.8525])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7237, 0.7821, 0.8260, 0.8261])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6837, 0.5392, 0.8333, 0.8094])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7056, 0.6452, 0.8132, 0.5453])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7101, 0.8456, 0.6939])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7145, 0.8609, 0.3381])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7421, 0.8688, 0.7218, 0.5160])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6871, 0.7972, 0.6405, 0.5152])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7269, 0.8057, 0.7062, 0.6954])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6987, 0.8405, 0.7261, 0.6775])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6639, 0.8497, 0.6855, 0.8772])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6571, 0.8313, 0.8097, 0.7759])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6915, 0.8357, 0.8280, 0.8030])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6808, 0.8589, 0.8874, 0.7497])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6666, 0.8153, 0.8446, 0.8591])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6505, 0.7490, 0.8984, 0.8467])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5965, 0.7234, 0.8565, 0.8509])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5768, 0.7537, 0.8800, 0.8814])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5263, 0.7815, 0.8825, 0.8140])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6907, 0.8339, 0.8560, 0.8811])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6924, 0.8623, 0.8765, 0.8296])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7342, 0.8848, 0.8618, 0.8565])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7358, 0.8917, 0.8127, 0.7899])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7554, 0.8953, 0.7111, 0.8151])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5828, 0.8632, 0.8690, 0.8052])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7003, 0.8694, 0.7907, 0.8237])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5399, 0.8511, 0.8668, 0.7695])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6427, 0.8350, 0.6437, 0.7399])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5939, 0.8536, 0.7671, 0.8444])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5977, 0.8616, 0.8396, 0.7914, 0.6936])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6521, 0.8778, 0.8613, 0.8074, 0.7397])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7270, 0.8648, 0.7905, 0.8329, 0.7785])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6331, 0.8842, 0.8196, 0.8468, 0.7443])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6070, 0.8763, 0.8591, 0.8083, 0.7265])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6645, 0.8686, 0.9098, 0.8596, 0.6826])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6888, 0.8955, 0.9199, 0.7704, 0.7232])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7281, 0.8850, 0.9036, 0.7608, 0.7905])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6805, 0.8786, 0.9079, 0.8034, 0.8299])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6999, 0.8878, 0.9190, 0.8448, 0.8188])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8809, 0.8934, 0.8898, 0.7964, 0.8416])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8613, 0.8976, 0.9045, 0.8720, 0.8331])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8379, 0.8998, 0.9264, 0.8548, 0.8216])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7933, 0.8945, 0.9170, 0.8801, 0.7920])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8032, 0.8755, 0.9253, 0.9124, 0.7874])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8499, 0.8532, 0.9307, 0.9117, 0.6165])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8662, 0.8704, 0.9270, 0.8877, 0.5390])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8643, 0.8703, 0.9055, 0.8301])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8722, 0.8860, 0.9383, 0.7644])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8696, 0.8938, 0.9380, 0.8061])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8597, 0.8686, 0.9416, 0.7355])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8769, 0.8804, 0.9360, 0.5469])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8877, 0.8778, 0.9302, 0.4277])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8856, 0.8610, 0.9304, 0.4592])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8772, 0.8734, 0.9383])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8854, 0.8628, 0.9130])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8916, 0.8585, 0.8484])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8876, 0.8816, 0.8466])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8878, 0.8621, 0.7242])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9009, 0.8856, 0.8239])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9083, 0.8835, 0.7622])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9059, 0.9035, 0.7337])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9127, 0.9045, 0.7904])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9245, 0.8996, 0.4916])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9171, 0.8862, 0.4942])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9224, 0.8746, 0.5525])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.9212, 0.8691, 0.7387])

# %% [markdown]
# ### Create images to compare original photo and predicted photo

# %%
import cv2
import numpy as np
from cv_functions import get_image_dimensions, resize_save

img_name = 'IMG_9402.JPG'
original_image_path = 'test_images/IMG_9402.JPG'
predicted_image_path = 'test_images/predict/IMG_9402.JPG'

original_img = cv2.imread(original_image_path)
predicted_img = cv2.imread(predicted_image_path)

h, w = get_image_dimensions(original_image_path)
if w > h:
    og_img = cv2.resize(original_img, (800, 800))
    predict_img = cv2.resize(predicted_img, (800, 800))
else:
    og_img = cv2.resize(original_img, (800, 800))
    predict_img = cv2.resize(predicted_img, (800, 800))

# Stacking the original image with the predicted image
result = np.hstack((og_img, predict_img))
# cv2.imshow('Result', result)
# cv2.waitKey(0)

cv2.imwrite(f'output/predicts/new/{img_name}_predicted.jpg', result)
# Out:
# True

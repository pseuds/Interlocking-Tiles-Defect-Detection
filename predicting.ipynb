# %% [markdown]
# ### Predicting

# %% [markdown]
# The following code performs predictions on `source` and returns `results`, which contains identified object data.
# <br><br>
# `model` : path to model.<br>
# `source`: image path / list of image paths / and more. See <a href="https://docs.ultralytics.com/modes/predict/">documentation</a>.<br>
# `conf`: confidence threshold.<br>
# `iou`: IoU threshold. <br>
# `imgsz`: size of image to infer with. current model was trained at 800.<br>

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a model
model = YOLO(model_path)  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(
    source=
        # 'datasets_sorted/PunggolMeridian_MRT/IMG_0008.JPG', 
        # 'datasets_sorted/PunggolMeridian_MRT/IMG_0019.JPG', 
        'datasets_sorted/PunggolMeridian_MRT', 
    
    conf=0.8, iou=0.5, imgsz=800
    )  # return a list of Results objects

# %% [markdown]
# #### Shows and save predicted image
#
# Change `save_path` to image path of choice.

# %%
from PIL import Image
import numpy as np
import cv2

save_path = "output/test/hehe.jpg"

# Process results list
for result in results:
    print(result.names)
    cls = result.boxes.cls  # Boxes object for bbox outputs
    conf = result.boxes.conf  # Boxes object for bbox outputs
    print(cls, conf)

    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    # print(masks.data)
    # print(type(masks.data))
    # print(keypoints)
    # print(probs)

    array = result.plot()
    array = array[:, :, ::-1]
    img = Image.fromarray(array)
    # img.show()

    img.save(save_path)

# %% [markdown]
# ### Predict image(s)/video

# %% [markdown]
# This directly saves predicted photo/video into a new folder.
#
# See <a href="https://docs.ultralytics.com/modes/predict/#inference-arguments">documentation</a> for more arguments.
#
# <br> <br>
# Change `image_path`, `image_paths`, or `video_path` and use either one of them in `source`.

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a pretrained YOLOv8n model
model = YOLO(model_path)
# Everton, Punggol_blk160_166, Punggol_EdgeField_BLK105, Punggol_EdgeField_BLK111, PunggolMeridian_MRT, TiongBahru
image_path = "output/test/IMG_0019.JPG"
image_paths = [
    "datasets_sorted/PunggolMeridian_MRT/IMG_0008.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0021.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0025.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0035.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_0041.JPG",
    "datasets_sorted/PunggolMeridian_MRT/IMG_9994.JPG",
    "datasets_sorted/TiongBahru/IMG_8823.JPG",
    "datasets_sorted/TiongBahru/IMG_8883.JPG",
    "datasets_sorted/TiongBahru/IMG_8884.JPG",
    "datasets_sorted/TiongBahru/IMG_8885.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8895.JPG",
    "datasets_sorted/TiongBahru/IMG_8926.JPG",
    "datasets_sorted/TiongBahru/IMG_8997.JPG",
    "datasets_sorted/TiongBahru/IMG_9012.JPG",
    "datasets_sorted/TiongBahru/IMG_9015.JPG",
]
# folder_path
video_path = "output/videos/GH012496_processed.mp4"

# Run inference on with arguments, change source if needed
model.predict(source=video_path, save=True, imgsz=800, conf=0.5)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 415.6ms
# video 1/1 (2/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 415.6ms
# video 1/1 (3/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 436.1ms
# video 1/1 (4/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 410.1ms
# video 1/1 (5/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 385.2ms
# video 1/1 (6/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 375.5ms
# video 1/1 (7/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 384.0ms
# video 1/1 (8/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 368.5ms
# video 1/1 (9/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 401.2ms
# video 1/1 (10/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 396.1ms
# video 1/1 (11/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 372.0ms
# video 1/1 (12/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 404.1ms
# video 1/1 (13/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 396.0ms
# video 1/1 (14/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 365.1ms
# video 1/1 (15/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -fade-s, 2 road marking -good-s, 347.5ms
# video 1/1 (16/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 353.6ms
# video 1/1 (17/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 365.0ms
# video 1/1 (18/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -good-, 409.0ms
# video 1/1 (19/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 366.1ms
# video 1/1 (20/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 361.1ms
# video 1/1 (21/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 423.0ms
# video 1/1 (22/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 415.3ms
# video 1/1 (23/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 2 road marking -good-s, 376.7ms
# video 1/1 (24/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 2 road marking -good-s, 407.1ms
# video 1/1 (25/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 389.0ms
# video 1/1 (26/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 371.0ms
# video 1/1 (27/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 392.1ms
# video 1/1 (28/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 389.1ms
# video 1/1 (29/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 2 road marking -good-s, 438.1ms
# video 1/1 (30/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 427.1ms
# video 1/1 (31/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 385.3ms
# video 1/1 (32/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 368.1ms
# video 1/1 (33/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 406.7ms
# video 1/1 (34/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 386.1ms
# video 1/1 (35/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 348.5ms
# video 1/1 (36/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 2 road marking -good-s, 387.1ms
# video 1/1 (37/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 397.1ms
# video 1/1 (38/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 375.1ms
# video 1/1 (39/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 383.1ms
# video 1/1 (40/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 403.1ms
# video 1/1 (41/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 406.1ms
# video 1/1 (42/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 2 road marking -good-s, 409.1ms
# video 1/1 (43/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 2 road marking -good-s, 395.1ms
# video 1/1 (44/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -fade-s, 2 road marking -good-s, 405.1ms
# video 1/1 (45/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 1 interlocking-tiles, 1 road marking -fade-, 2 road marking -good-s, 377.1ms
# video 1/1 (46/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 1 interlocking-tiles, 2 road marking -good-s, 360.6ms
# video 1/1 (47/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 420.1ms
# video 1/1 (48/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 400.1ms
# video 1/1 (49/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 390.1ms
# video 1/1 (50/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 4 road marking -good-s, 394.1ms
# video 1/1 (51/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 3 road marking -good-s, 373.5ms
# video 1/1 (52/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 4 road marking -good-s, 386.0ms
# video 1/1 (53/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 3 road marking -good-s, 363.6ms
# video 1/1 (54/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 364.1ms
# video 1/1 (55/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 419.6ms
# video 1/1 (56/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 449.5ms
# video 1/1 (57/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 397.1ms
# video 1/1 (58/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 431.6ms
# video 1/1 (59/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 411.1ms
# video 1/1 (60/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 375.1ms
# video 1/1 (61/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 414.1ms
# video 1/1 (62/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 399.0ms
# video 1/1 (63/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 398.8ms
# video 1/1 (64/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 386.3ms
# video 1/1 (65/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 400.1ms
# video 1/1 (66/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 371.1ms
# video 1/1 (67/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 400.1ms
# video 1/1 (68/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 423.6ms
# video 1/1 (69/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 425.2ms
# video 1/1 (70/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 405.0ms
# video 1/1 (71/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 386.1ms
# video 1/1 (72/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 422.6ms
# video 1/1 (73/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 388.1ms
# video 1/1 (74/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 409.0ms
# video 1/1 (75/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 386.0ms
# video 1/1 (76/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 397.1ms
# video 1/1 (77/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 419.1ms
# video 1/1 (78/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 400.1ms
# video 1/1 (79/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 2 road marking -good-s, 411.1ms
# video 1/1 (80/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 407.1ms
# video 1/1 (81/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 401.0ms
# video 1/1 (82/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 396.0ms
# video 1/1 (83/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 420.0ms
# video 1/1 (84/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 412.0ms
# video 1/1 (85/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 418.1ms
# video 1/1 (86/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 362.5ms
# video 1/1 (87/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 386.1ms
# video 1/1 (88/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 384.1ms
# video 1/1 (89/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 391.1ms
# video 1/1 (90/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 397.5ms
# video 1/1 (91/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 427.6ms
# video 1/1 (92/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 426.1ms
# video 1/1 (93/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 383.2ms
# video 1/1 (94/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 424.1ms
# video 1/1 (95/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 404.1ms
# video 1/1 (96/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 421.0ms
# video 1/1 (97/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 376.0ms
# video 1/1 (98/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 419.1ms
# video 1/1 (99/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 390.5ms
# video 1/1 (100/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 405.9ms
# video 1/1 (101/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 381.0ms
# video 1/1 (102/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 389.1ms
# video 1/1 (103/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 372.7ms
# video 1/1 (104/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 404.2ms
# video 1/1 (105/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 404.1ms
# video 1/1 (106/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 396.1ms
# video 1/1 (107/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 378.1ms
# video 1/1 (108/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 377.1ms
# video 1/1 (109/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 392.1ms
# video 1/1 (110/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 409.2ms
# video 1/1 (111/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 414.2ms
# video 1/1 (112/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 436.0ms
# video 1/1 (113/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 402.1ms
# video 1/1 (114/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 367.1ms
# video 1/1 (115/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 367.1ms
# video 1/1 (116/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 395.1ms
# video 1/1 (117/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 396.5ms
# video 1/1 (118/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 371.1ms
# video 1/1 (119/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 413.6ms
# video 1/1 (120/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 399.1ms
# video 1/1 (121/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 404.1ms
# video 1/1 (122/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 395.0ms
# video 1/1 (123/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 373.1ms
# video 1/1 (124/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 421.1ms
# video 1/1 (125/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 433.1ms
# video 1/1 (126/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 395.1ms
# video 1/1 (127/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 390.1ms
# video 1/1 (128/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 384.1ms
# video 1/1 (129/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 412.1ms
# video 1/1 (130/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 386.1ms
# video 1/1 (131/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 388.1ms
# video 1/1 (132/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 366.6ms
# video 1/1 (133/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 431.1ms
# video 1/1 (134/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 438.1ms
# video 1/1 (135/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 400.1ms
# video 1/1 (136/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 389.0ms
# video 1/1 (137/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 368.5ms
# video 1/1 (138/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 manhole, 3 road marking -fade-s, 1 road marking -good-, 366.1ms
# video 1/1 (139/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 1 asphalts, 3 interlocking-tiless, 3 road marking -fade-s, 1 road marking -good-, 381.1ms
# video 1/1 (140/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 3 road marking -fade-s, 1 road marking -good-, 427.6ms
# video 1/1 (141/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 380.6ms
# video 1/1 (142/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 4 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 402.1ms
# video 1/1 (143/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 343.5ms
# video 1/1 (144/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 404.1ms
# video 1/1 (145/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 396.1ms
# video 1/1 (146/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 407.1ms
# video 1/1 (147/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 395.2ms
# video 1/1 (148/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 357.1ms
# video 1/1 (149/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 373.6ms
# video 1/1 (150/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 371.0ms
# video 1/1 (151/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 378.6ms
# video 1/1 (152/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 379.0ms
# video 1/1 (153/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 1 road marking -good-, 418.0ms
# video 1/1 (154/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 393.0ms
# video 1/1 (155/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 430.0ms
# video 1/1 (156/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 388.1ms
# video 1/1 (157/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 427.1ms
# video 1/1 (158/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 417.6ms
# video 1/1 (159/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 378.1ms
# video 1/1 (160/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 405.1ms
# video 1/1 (161/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 417.1ms
# video 1/1 (162/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 424.6ms
# video 1/1 (163/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 397.1ms
# video 1/1 (164/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 431.1ms
# video 1/1 (165/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 390.5ms
# video 1/1 (166/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 414.1ms
# video 1/1 (167/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 402.1ms
# video 1/1 (168/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 409.1ms
# video 1/1 (169/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 383.5ms
# video 1/1 (170/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 400.1ms
# video 1/1 (171/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 393.1ms
# video 1/1 (172/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 390.5ms
# video 1/1 (173/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 461.6ms
# video 1/1 (174/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 377.1ms
# video 1/1 (175/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 387.0ms
# video 1/1 (176/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 380.1ms
# video 1/1 (177/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 398.1ms
# video 1/1 (178/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 408.7ms
# video 1/1 (179/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 417.1ms
# video 1/1 (180/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 384.0ms
# video 1/1 (181/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 387.5ms
# video 1/1 (182/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 428.1ms
# video 1/1 (183/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 404.1ms
# video 1/1 (184/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 422.0ms
# video 1/1 (185/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 360.0ms
# video 1/1 (186/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 411.1ms
# video 1/1 (187/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 366.1ms
# video 1/1 (188/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 397.1ms
# video 1/1 (189/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 390.1ms
# video 1/1 (190/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 394.0ms
# video 1/1 (191/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 385.0ms
# video 1/1 (192/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 388.1ms
# video 1/1 (193/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 378.0ms
# video 1/1 (194/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 378.2ms
# video 1/1 (195/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 389.1ms
# video 1/1 (196/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 406.1ms
# video 1/1 (197/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 380.0ms
# video 1/1 (198/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 392.0ms
# video 1/1 (199/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 3 road marking -fade-s, 393.1ms
# video 1/1 (200/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 394.1ms
# video 1/1 (201/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 409.1ms
# video 1/1 (202/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 385.1ms
# video 1/1 (203/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 416.1ms
# video 1/1 (204/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 382.7ms
# video 1/1 (205/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 403.2ms
# video 1/1 (206/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 410.1ms
# video 1/1 (207/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 404.1ms
# video 1/1 (208/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 401.0ms
# video 1/1 (209/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 379.1ms
# video 1/1 (210/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 391.0ms
# video 1/1 (211/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 414.1ms
# video 1/1 (212/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 380.1ms
# video 1/1 (213/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 392.1ms
# video 1/1 (214/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 380.1ms
# video 1/1 (215/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 426.1ms
# video 1/1 (216/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 387.1ms
# video 1/1 (217/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 394.1ms
# video 1/1 (218/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 413.1ms
# video 1/1 (219/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 395.0ms
# video 1/1 (220/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 410.0ms
# video 1/1 (221/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 394.1ms
# video 1/1 (222/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 402.1ms
# video 1/1 (223/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 370.2ms
# video 1/1 (224/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 3 road marking -good-s, 367.0ms
# video 1/1 (225/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 364.5ms
# video 1/1 (226/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 418.1ms
# video 1/1 (227/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 375.5ms
# video 1/1 (228/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 3 road marking -good-s, 378.0ms
# video 1/1 (229/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 399.0ms
# video 1/1 (230/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 3 road marking -good-s, 392.0ms
# video 1/1 (231/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 413.7ms
# video 1/1 (232/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 3 road marking -good-s, 376.1ms
# video 1/1 (233/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 2 road marking -good-s, 399.0ms
# video 1/1 (234/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 362.0ms
# video 1/1 (235/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 454.3ms
# video 1/1 (236/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 2 road marking -good-s, 419.6ms
# video 1/1 (237/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 393.1ms
# video 1/1 (238/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 402.1ms
# video 1/1 (239/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 381.1ms
# video 1/1 (240/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 384.0ms
# video 1/1 (241/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 404.1ms
# video 1/1 (242/294) c:\D drive\2023 intern\Interlocking-Tiles-Defect-Detection\output\videos\GH012496_processed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 395.0ms
# ...
#          [ 55,  57,  50]],
#
#         ...,
#
#         [[ 53,  47,  55],
#          [ 66,  60,  68],
#          [ 67,  65,  70],
#          ...,
#          [ 95,  83,  95],
#          [ 92,  81,  90],
#          [ 86,  75,  84]],
#
#         [[ 41,  39,  44],
#          [ 64,  62,  67],
#          [ 64,  62,  67],
#          ...,
#          [ 94,  82,  94],
#          [ 92,  81,  90],
#          [ 86,  75,  84]],
#
#         [[ 48,  46,  51],
#          [ 61,  59,  64],
#          [ 61,  59,  64],
#          ...,
#          [ 93,  81,  93],
#          [ 91,  80,  89],
#          [ 86,  75,  84]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 2.0003318786621094, 'inference': 408.0832004547119, 'postprocess': 4.999399185180664},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 60,  37,  48],
#          [ 67,  44,  55],
#          [ 75,  50,  66],
#          ...,
#          [ 78,  80,  73],
#          [ 76,  78,  71],
#          [ 73,  75,  68]],
#
#         [[ 55,  32,  43],
#          [ 69,  46,  57],
#          [ 75,  50,  66],
#          ...,
#          [ 59,  61,  54],
#          [ 51,  53,  46],
#          [ 52,  54,  47]],
#
#         [[ 30,   9,  22],
#          [ 47,  26,  39],
#          [151, 132, 145],
#          ...,
#          [ 46,  48,  41],
#          [ 25,  27,  20],
#          [ 34,  36,  29]],
#
#         ...,
#
#         [[ 86,  83,  90],
#          [ 52,  49,  56],
#          [ 87,  84,  91],
#          ...,
#          [ 36,  25,  34],
#          [ 29,  18,  27],
#          [  7,   0,   5]],
#
#         [[ 85,  82,  89],
#          [ 80,  77,  84],
#          [119, 116, 123],
#          ...,
#          [ 49,  38,  47],
#          [ 49,  38,  47],
#          [ 63,  52,  61]],
#
#         [[ 88,  85,  92],
#          [ 98,  95, 102],
#          [112, 109, 116],
#          ...,
#          [ 42,  31,  40],
#          [ 57,  46,  55],
#          [113, 102, 111]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 2.0017623901367188, 'inference': 380.1007270812988, 'postprocess': 5.003690719604492},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 50,  26,  40],
#          [ 66,  42,  56],
#          [ 41,  19,  34],
#          ...,
#          [ 88,  90,  83],
#          [ 83,  85,  78],
#          [ 85,  87,  80]],
#
#         [[ 54,  30,  44],
#          [ 66,  42,  56],
#          [ 47,  25,  40],
#          ...,
#          [ 97,  99,  92],
#          [ 71,  73,  66],
#          [ 61,  63,  56]],
#
#         [[ 44,  23,  36],
#          [ 83,  62,  75],
#          [180, 161, 174],
#          ...,
#          [ 74,  76,  69],
#          [ 72,  74,  67],
#          [ 52,  54,  47]],
#
#         ...,
#
#         [[ 10,  12,  19],
#          [ 28,  30,  37],
#          [166, 171, 177],
#          ...,
#          [ 93,  80,  94],
#          [ 86,  74,  86],
#          [ 86,  74,  86]],
#
#         [[ 34,  36,  43],
#          [ 86,  88,  95],
#          [147, 149, 156],
#          ...,
#          [ 87,  74,  88],
#          [ 85,  73,  85],
#          [ 88,  76,  88]],
#
#         [[ 63,  65,  72],
#          [154, 156, 163],
#          [127, 129, 136],
#          ...,
#          [ 73,  60,  74],
#          [ 71,  59,  71],
#          [ 75,  63,  75]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 2.999544143676758, 'inference': 406.0509204864502, 'postprocess': 4.995822906494141},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 59,  39,  54],
#          [ 60,  40,  55],
#          [ 56,  46,  53],
#          ...,
#          [ 65,  67,  60],
#          [ 85,  87,  80],
#          [ 88,  90,  83]],
#
#         [[ 57,  37,  52],
#          [ 59,  39,  54],
#          [ 33,  23,  30],
#          ...,
#          [ 67,  69,  62],
#          [ 87,  89,  82],
#          [ 83,  85,  78]],
#
#         [[ 45,  26,  39],
#          [101,  82,  95],
#          [153, 144, 148],
#          ...,
#          [ 65,  67,  60],
#          [ 72,  74,  67],
#          [ 82,  84,  77]],
#
#         ...,
#
#         [[171, 178, 184],
#          [158, 165, 171],
#          [151, 158, 164],
#          ...,
#          [ 89,  77,  89],
#          [ 80,  68,  80],
#          [ 92,  80,  92]],
#
#         [[188, 195, 201],
#          [176, 183, 189],
#          [147, 154, 160],
#          ...,
#          [ 99,  87,  99],
#          [123, 111, 123],
#          [108,  96, 108]],
#
#         [[197, 204, 210],
#          [174, 181, 187],
#          [151, 158, 164],
#          ...,
#          [100,  88, 100],
#          [129, 117, 129],
#          [ 95,  83,  95]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 2.0003318786621094, 'inference': 429.52561378479004, 'postprocess': 11.000394821166992},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 79,  69,  76],
#          [ 39,  29,  36],
#          [ 40,  40,  38],
#          ...,
#          [ 55,  56,  51],
#          [ 61,  62,  57],
#          [ 65,  66,  61]],
#
#         [[ 54,  44,  51],
#          [ 38,  28,  35],
#          [ 43,  43,  41],
#          ...,
#          [ 55,  56,  51],
#          [ 61,  62,  57],
#          [ 65,  66,  61]],
#
#         [[ 42,  33,  37],
#          [ 16,   7,  11],
#          [ 61,  61,  59],
#          ...,
#          [ 55,  56,  51],
#          [ 61,  62,  57],
#          [ 65,  66,  61]],
#
#         ...,
#
#         [[116, 121, 132],
#          [130, 135, 146],
#          [116, 121, 132],
#          ...,
#          [ 84,  74,  81],
#          [ 81,  70,  79],
#          [ 81,  70,  79]],
#
#         [[112, 117, 128],
#          [110, 115, 126],
#          [103, 108, 119],
#          ...,
#          [ 87,  76,  85],
#          [ 82,  70,  82],
#          [ 80,  68,  80]],
#
#         [[120, 125, 136],
#          [ 89,  94, 105],
#          [101, 106, 117],
#          ...,
#          [ 86,  75,  84],
#          [ 85,  73,  85],
#          [ 85,  73,  85]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 4.000186920166016, 'inference': 412.5485420227051, 'postprocess': 7.999420166015625},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 45,  39,  42],
#          [ 51,  45,  48],
#          [ 55,  58,  56],
#          ...,
#          [ 45,  46,  41],
#          [ 50,  51,  46],
#          [ 55,  56,  51]],
#
#         [[ 51,  45,  48],
#          [ 44,  38,  41],
#          [ 42,  45,  43],
#          ...,
#          [ 45,  46,  41],
#          [ 50,  51,  46],
#          [ 55,  56,  51]],
#
#         [[ 20,  15,  16],
#          [ 37,  32,  33],
#          [ 30,  34,  29],
#          ...,
#          [ 44,  45,  40],
#          [ 50,  51,  46],
#          [ 57,  58,  53]],
#
#         ...,
#
#         [[155, 155, 167],
#          [162, 162, 174],
#          [146, 146, 158],
#          ...,
#          [ 94,  84,  91],
#          [ 94,  83,  92],
#          [100,  89,  98]],
#
#         [[161, 164, 175],
#          [165, 168, 179],
#          [132, 132, 144],
#          ...,
#          [ 91,  81,  88],
#          [ 92,  81,  90],
#          [ 93,  82,  91]],
#
#         [[171, 174, 185],
#          [139, 142, 153],
#          [171, 171, 183],
#          ...,
#          [ 89,  79,  86],
#          [ 91,  80,  89],
#          [ 93,  82,  91]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 3.000020980834961, 'inference': 389.04285430908203, 'postprocess': 9.999990463256836},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 14,  12,   8],
#          [ 10,   8,   4],
#          [ 32,  34,  27],
#          ...,
#          [ 57,  58,  53],
#          [ 55,  56,  51],
#          [ 55,  56,  51]],
#
#         [[ 90,  88,  84],
#          [ 77,  75,  71],
#          [ 17,  19,  12],
#          ...,
#          [ 57,  58,  53],
#          [ 55,  56,  51],
#          [ 55,  56,  51]],
#
#         [[229, 230, 225],
#          [206, 207, 202],
#          [ 87,  92,  85],
#          ...,
#          [ 53,  54,  49],
#          [ 55,  56,  51],
#          [ 57,  58,  53]],
#
#         ...,
#
#         [[156, 158, 165],
#          [181, 183, 190],
#          [180, 182, 189],
#          ...,
#          [120, 108, 120],
#          [125, 113, 125],
#          [ 70,  58,  70]],
#
#         [[155, 157, 164],
#          [180, 182, 189],
#          [177, 179, 186],
#          ...,
#          [102,  90, 102],
#          [138, 126, 138],
#          [ 78,  66,  78]],
#
#         [[155, 157, 164],
#          [168, 170, 177],
#          [131, 133, 140],
#          ...,
#          [107,  95, 107],
#          [116, 104, 116],
#          [ 39,  27,  39]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 2.0020008087158203, 'inference': 415.0519371032715, 'postprocess': 10.999917984008789},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 46,  31,  40],
#          [ 29,  14,  23],
#          [206, 206, 206],
#          ...,
#          [ 46,  52,  47],
#          [ 35,  41,  36],
#          [ 52,  58,  53]],
#
#         [[ 74,  59,  68],
#          [ 46,  31,  40],
#          [220, 220, 220],
#          ...,
#          [ 46,  52,  47],
#          [ 36,  42,  37],
#          [ 52,  58,  53]],
#
#         [[ 53,  40,  49],
#          [ 37,  24,  33],
#          [210, 210, 210],
#          ...,
#          [ 52,  58,  53],
#          [ 39,  45,  40],
#          [ 49,  55,  50]],
#
#         ...,
#
#         [[ 80,  77,  84],
#          [ 30,  27,  34],
#          [ 72,  69,  76],
#          ...,
#          [112, 103, 114],
#          [ 40,  32,  40],
#          [ 47,  39,  47]],
#
#         [[138, 135, 142],
#          [ 31,  28,  35],
#          [ 36,  33,  40],
#          ...,
#          [147, 138, 149],
#          [ 37,  29,  37],
#          [ 44,  36,  44]],
#
#         [[173, 170, 177],
#          [ 46,  43,  50],
#          [ 37,  34,  41],
#          ...,
#          [136, 127, 138],
#          [ 55,  47,  55],
#          [ 41,  33,  41]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 1.9996166229248047, 'inference': 407.09877014160156, 'postprocess': 3.999948501586914},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[186, 180, 183],
#          [189, 183, 186],
#          [ 37,  50,  39],
#          ...,
#          [ 43,  49,  44],
#          [ 45,  51,  46],
#          [ 42,  48,  43]],
#
#         [[ 19,  13,  16],
#          [ 38,  32,  35],
#          [ 58,  71,  60],
#          ...,
#          [ 39,  45,  40],
#          [ 45,  51,  46],
#          [ 47,  53,  48]],
#
#         [[ 15,  10,  11],
#          [135, 130, 131],
#          [ 34,  47,  36],
#          ...,
#          [ 66,  72,  67],
#          [ 76,  82,  77],
#          [ 64,  70,  65]],
#
#         ...,
#
#         [[ 81,  78,  85],
#          [ 78,  75,  82],
#          [ 76,  74,  79],
#          ...,
#          [ 55,  48,  59],
#          [ 42,  35,  46],
#          [ 28,  21,  32]],
#
#         [[ 88,  85,  92],
#          [ 75,  72,  79],
#          [ 80,  78,  83],
#          ...,
#          [109, 102, 113],
#          [ 57,  50,  61],
#          [ 47,  40,  51]],
#
#         [[ 88,  85,  92],
#          [ 72,  69,  76],
#          [ 73,  71,  76],
#          ...,
#          [ 99,  92, 103],
#          [100,  93, 104],
#          [ 71,  64,  75]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 3.0014514923095703, 'inference': 382.05456733703613, 'postprocess': 4.996776580810547},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
#  orig_img: array([[[ 39,  44,  55],
#          [ 37,  42,  53],
#          [153, 174, 153],
#          ...,
#          [ 72,  73,  68],
#          [ 83,  87,  82],
#          [ 70,  74,  69]],
#
#         [[156, 161, 172],
#          [143, 148, 159],
#          [129, 150, 129],
#          ...,
#          [ 65,  66,  61],
#          [ 70,  74,  69],
#          [ 62,  66,  61]],
#
#         [[220, 223, 234],
#          [238, 241, 252],
#          [136, 153, 135],
#          ...,
#          [ 55,  56,  51],
#          [ 59,  63,  58],
#          [ 63,  67,  62]],
#
#         ...,
#
#         [[ 97,  95, 100],
#          [ 90,  88,  93],
#          [ 80,  78,  83],
#          ...,
#          [173, 166, 177],
#          [137, 130, 141],
#          [141, 134, 145]],
#
#         [[100,  98, 103],
#          [ 94,  92,  97],
#          [ 89,  87,  92],
#          ...,
#          [134, 127, 138],
#          [147, 140, 151],
#          [124, 117, 128]],
#
#         [[ 93,  91,  96],
#          [ 87,  85,  90],
#          [ 83,  81,  86],
#          ...,
#          [ 40,  33,  44],
#          [137, 130, 141],
#          [165, 158, 169]]], dtype=uint8)
#  orig_shape: (800, 800)
#  path: 'c:\\D drive\\2023 intern\\Interlocking-Tiles-Defect-Detection\\output\\videos\\GH012496_processed.mp4'
#  probs: None
#  save_dir: 'runs\\segment\\predict17'
#  speed: {'preprocess': 3.999948501586914, 'inference': 426.06210708618164, 'postprocess': 5.9986114501953125}]

# %% [markdown]
# ### Model Track
#
# Takes in a video at `video_path` and performs object tracking. Produces `results` for plotting later.
#
# See <a href="https://docs.ultralytics.com/modes/track/">documentation</a>.
#
# Change `model_path` to path to model. <br>
# Change `video_path` to video of choice.

# %%
from ultralytics import YOLO

model_path = "datasets/YOLOv8_1/train_2/weights/best.pt"

# Load a pretrained YOLOv8n model
model = YOLO(model_path)

video_path = "C:/D drive/2023 intern/Interlocking Tiles Defect Detection GUI/test/vid-img-in/GH012496_trimmed.mp4"

# Run inference on 'bus.jpg' with arguments
results = model.track(source=video_path, conf=0.3, iou=0.5, show=False)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 510.6ms
# video 1/1 (2/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 443.1ms
# video 1/1 (3/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 463.6ms
# video 1/1 (4/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 463.6ms
# video 1/1 (5/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 425.8ms
# video 1/1 (6/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 437.1ms
# video 1/1 (7/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 450.1ms
# video 1/1 (8/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 437.8ms
# video 1/1 (9/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 432.6ms
# video 1/1 (10/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 423.2ms
# video 1/1 (11/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 460.0ms
# video 1/1 (12/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 447.2ms
# video 1/1 (13/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 443.0ms
# video 1/1 (14/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 440.7ms
# video 1/1 (15/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 464.6ms
# video 1/1 (16/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 410.7ms
# video 1/1 (17/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 443.0ms
# video 1/1 (18/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 415.1ms
# video 1/1 (19/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 463.1ms
# video 1/1 (20/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 451.5ms
# video 1/1 (21/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 449.5ms
# video 1/1 (22/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 356.1ms
# video 1/1 (23/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 393.2ms
# video 1/1 (24/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 409.6ms
# video 1/1 (25/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 428.7ms
# video 1/1 (26/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 452.3ms
# video 1/1 (27/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 464.1ms
# video 1/1 (28/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 421.7ms
# video 1/1 (29/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 406.0ms
# video 1/1 (30/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 407.3ms
# video 1/1 (31/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 431.2ms
# video 1/1 (32/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 435.1ms
# video 1/1 (33/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 401.1ms
# video 1/1 (34/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 421.0ms
# video 1/1 (35/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 2 road marking -fade-s, 428.9ms
# video 1/1 (36/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 2 road marking -fade-s, 431.6ms
# video 1/1 (37/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 419.2ms
# video 1/1 (38/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 419.2ms
# video 1/1 (39/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 419.1ms
# video 1/1 (40/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 368.6ms
# video 1/1 (41/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 429.1ms
# video 1/1 (42/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 365.1ms
# video 1/1 (43/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 440.6ms
# video 1/1 (44/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 2 road marking -fade-s, 401.1ms
# video 1/1 (45/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 407.1ms
# video 1/1 (46/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 422.0ms
# video 1/1 (47/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 401.1ms
# video 1/1 (48/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 423.1ms
# video 1/1 (49/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 387.7ms
# video 1/1 (50/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 417.0ms
# video 1/1 (51/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 379.1ms
# video 1/1 (52/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 402.0ms
# video 1/1 (53/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 394.0ms
# video 1/1 (54/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 424.6ms
# video 1/1 (55/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 445.1ms
# video 1/1 (56/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 394.1ms
# video 1/1 (57/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 435.6ms
# video 1/1 (58/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 399.2ms
# video 1/1 (59/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 441.4ms
# video 1/1 (60/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 416.1ms
# video 1/1 (61/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 444.1ms
# video 1/1 (62/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 409.1ms
# video 1/1 (63/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 439.0ms
# video 1/1 (64/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 412.1ms
# video 1/1 (65/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 454.6ms
# video 1/1 (66/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 420.0ms
# video 1/1 (67/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 417.0ms
# video 1/1 (68/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 431.1ms
# video 1/1 (69/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 383.9ms
# video 1/1 (70/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 393.0ms
# video 1/1 (71/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 401.0ms
# video 1/1 (72/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 421.0ms
# video 1/1 (73/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 413.5ms
# video 1/1 (74/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 410.4ms
# video 1/1 (75/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 386.0ms
# video 1/1 (76/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 421.3ms
# video 1/1 (77/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 398.6ms
# video 1/1 (78/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 439.4ms
# video 1/1 (79/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 404.8ms
# video 1/1 (80/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 428.6ms
# video 1/1 (81/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 439.2ms
# video 1/1 (82/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 408.7ms
# video 1/1 (83/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 444.1ms
# video 1/1 (84/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 397.1ms
# video 1/1 (85/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 439.2ms
# video 1/1 (86/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 391.1ms
# video 1/1 (87/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 472.1ms
# video 1/1 (88/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 425.1ms
# video 1/1 (89/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 423.7ms
# video 1/1 (90/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 428.1ms
# video 1/1 (91/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 403.9ms
# video 1/1 (92/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 419.0ms
# video 1/1 (93/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 412.0ms
# video 1/1 (94/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 420.7ms
# video 1/1 (95/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 426.9ms
# video 1/1 (96/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 432.1ms
# video 1/1 (97/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 411.1ms
# video 1/1 (98/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 441.6ms
# video 1/1 (99/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 393.9ms
# video 1/1 (100/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 439.6ms
# video 1/1 (101/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 395.1ms
# video 1/1 (102/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 448.1ms
# video 1/1 (103/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 424.9ms
# video 1/1 (104/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 385.8ms
# video 1/1 (105/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 438.6ms
# video 1/1 (106/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 381.8ms
# video 1/1 (107/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 440.6ms
# video 1/1 (108/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 425.7ms
# video 1/1 (109/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 414.7ms
# video 1/1 (110/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 433.1ms
# video 1/1 (111/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 403.1ms
# video 1/1 (112/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 381.0ms
# video 1/1 (113/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 410.0ms
# video 1/1 (114/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 419.0ms
# video 1/1 (115/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 375.1ms
# video 1/1 (116/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 422.6ms
# video 1/1 (117/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 377.0ms
# video 1/1 (118/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 419.2ms
# video 1/1 (119/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 390.5ms
# video 1/1 (120/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 393.9ms
# video 1/1 (121/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 415.1ms
# video 1/1 (122/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 389.6ms
# video 1/1 (123/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 431.7ms
# video 1/1 (124/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 396.0ms
# video 1/1 (125/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 436.2ms
# video 1/1 (126/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 398.1ms
# video 1/1 (127/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 418.1ms
# video 1/1 (128/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 404.1ms
# video 1/1 (129/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 424.2ms
# video 1/1 (130/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 406.1ms
# video 1/1 (131/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 432.1ms
# video 1/1 (132/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 444.2ms
# video 1/1 (133/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 381.0ms
# video 1/1 (134/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 412.1ms
# video 1/1 (135/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 416.0ms
# video 1/1 (136/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 425.6ms
# video 1/1 (137/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 400.1ms
# video 1/1 (138/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 428.1ms
# video 1/1 (139/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 asphalts, 2 interlocking-tiless, 1 road marking -fade-, 424.2ms
# video 1/1 (140/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 410.1ms
# video 1/1 (141/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 391.1ms
# video 1/1 (142/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 356.0ms
# video 1/1 (143/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 460.1ms
# video 1/1 (144/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 388.2ms
# video 1/1 (145/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 429.6ms
# video 1/1 (146/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 413.8ms
# video 1/1 (147/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 437.6ms
# video 1/1 (148/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 422.1ms
# video 1/1 (149/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 463.1ms
# video 1/1 (150/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 418.0ms
# video 1/1 (151/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 427.2ms
# video 1/1 (152/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 424.8ms
# video 1/1 (153/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 428.6ms
# video 1/1 (154/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 421.1ms
# video 1/1 (155/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 406.1ms
# video 1/1 (156/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 429.7ms
# video 1/1 (157/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 417.1ms
# video 1/1 (158/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 435.1ms
# video 1/1 (159/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 422.1ms
# video 1/1 (160/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 455.6ms
# video 1/1 (161/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 416.2ms
# video 1/1 (162/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 450.3ms
# video 1/1 (163/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 402.1ms
# video 1/1 (164/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 406.1ms
# video 1/1 (165/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 385.1ms
# video 1/1 (166/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 382.1ms
# video 1/1 (167/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 427.6ms
# video 1/1 (168/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 425.9ms
# video 1/1 (169/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 425.0ms
# video 1/1 (170/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 390.1ms
# video 1/1 (171/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 451.6ms
# video 1/1 (172/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 436.8ms
# video 1/1 (173/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 402.2ms
# video 1/1 (174/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 397.1ms
# video 1/1 (175/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 389.0ms
# video 1/1 (176/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 422.1ms
# video 1/1 (177/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 381.1ms
# video 1/1 (178/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 409.2ms
# video 1/1 (179/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 374.6ms
# video 1/1 (180/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 432.2ms
# video 1/1 (181/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 405.1ms
# video 1/1 (182/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 388.1ms
# video 1/1 (183/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 444.1ms
# video 1/1 (184/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 419.3ms
# video 1/1 (185/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 412.0ms
# video 1/1 (186/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 393.1ms
# video 1/1 (187/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 423.1ms
# video 1/1 (188/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 418.7ms
# video 1/1 (189/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 407.0ms
# video 1/1 (190/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 424.6ms
# video 1/1 (191/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 408.2ms
# video 1/1 (192/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 429.1ms
# video 1/1 (193/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 398.1ms
# video 1/1 (194/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 450.6ms
# video 1/1 (195/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 413.1ms
# video 1/1 (196/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 444.1ms
# video 1/1 (197/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 401.0ms
# video 1/1 (198/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 424.2ms
# video 1/1 (199/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 412.1ms
# video 1/1 (200/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 375.5ms
# video 1/1 (201/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 450.3ms
# video 1/1 (202/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 399.8ms
# video 1/1 (203/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 414.0ms
# video 1/1 (204/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 400.9ms
# video 1/1 (205/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 426.1ms
# video 1/1 (206/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 427.5ms
# video 1/1 (207/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 438.2ms
# video 1/1 (208/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 398.6ms
# video 1/1 (209/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 400.0ms
# video 1/1 (210/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 435.6ms
# video 1/1 (211/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 422.0ms
# video 1/1 (212/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 474.1ms
# video 1/1 (213/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 446.6ms
# video 1/1 (214/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 390.5ms
# video 1/1 (215/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 368.0ms
# video 1/1 (216/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 422.0ms
# video 1/1 (217/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 384.0ms
# video 1/1 (218/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 452.2ms
# video 1/1 (219/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 426.4ms
# video 1/1 (220/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 437.7ms
# video 1/1 (221/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 366.1ms
# video 1/1 (222/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 403.9ms
# video 1/1 (223/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 403.3ms
# video 1/1 (224/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 425.3ms
# video 1/1 (225/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 455.2ms
# video 1/1 (226/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 393.9ms
# video 1/1 (227/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 444.6ms
# video 1/1 (228/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 413.1ms
# video 1/1 (229/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 425.7ms
# video 1/1 (230/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 408.1ms
# video 1/1 (231/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 382.1ms
# video 1/1 (232/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 435.2ms
# video 1/1 (233/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 403.1ms
# video 1/1 (234/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 401.1ms
# video 1/1 (235/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 398.1ms
# video 1/1 (236/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 407.1ms
# video 1/1 (237/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 394.0ms
# video 1/1 (238/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 395.1ms
# video 1/1 (239/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 389.0ms
# video 1/1 (240/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 395.1ms
# video 1/1 (241/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 434.0ms
# video 1/1 (242/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 431.1ms
# video 1/1 (243/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 437.6ms
# video 1/1 (244/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 412.2ms
# video 1/1 (245/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 445.6ms
# video 1/1 (246/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 427.6ms
# video 1/1 (247/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 420.1ms
# video 1/1 (248/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 430.7ms
# video 1/1 (249/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 440.1ms
# video 1/1 (250/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 436.1ms
# video 1/1 (251/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 430.0ms
# video 1/1 (252/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 427.8ms
# video 1/1 (253/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 403.2ms
# video 1/1 (254/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 408.1ms
# video 1/1 (255/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 439.0ms
# video 1/1 (256/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 421.1ms
# video 1/1 (257/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 425.1ms
# video 1/1 (258/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 407.1ms
# video 1/1 (259/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 399.1ms
# video 1/1 (260/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 440.7ms
# video 1/1 (261/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 413.1ms
# video 1/1 (262/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 455.1ms
# video 1/1 (263/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 410.1ms
# video 1/1 (264/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 404.1ms
# video 1/1 (265/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 427.1ms
# video 1/1 (266/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 392.1ms
# video 1/1 (267/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 398.1ms
# video 1/1 (268/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -good-, 413.5ms
# video 1/1 (269/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 415.6ms
# video 1/1 (270/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -good-, 423.1ms
# video 1/1 (271/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 409.1ms
# video 1/1 (272/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 416.1ms
# video 1/1 (273/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 420.1ms
# video 1/1 (274/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 3 interlocking-tiless, 1 road marking -fade-, 420.6ms
# video 1/1 (275/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 2 road marking -fade-s, 446.1ms
# video 1/1 (276/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 464.1ms
# video 1/1 (277/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 2 interlocking-tiless, 1 road marking -fade-, 1 road marking -good-, 437.6ms
# video 1/1 (278/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 405.1ms
# video 1/1 (279/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 416.1ms
# video 1/1 (280/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 1 road marking -good-, 407.2ms
# video 1/1 (281/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -fade-, 1 road marking -good-, 433.1ms
# video 1/1 (282/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -fade-, 1 road marking -good-, 460.9ms
# video 1/1 (283/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -good-, 479.5ms
# video 1/1 (284/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -good-, 547.9ms
# video 1/1 (285/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -good-, 481.4ms
# video 1/1 (286/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 road marking -fade-, 491.8ms
# video 1/1 (287/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 564.1ms
# video 1/1 (288/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 502.8ms
# video 1/1 (289/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 541.3ms
# video 1/1 (290/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -fade-, 535.6ms
# video 1/1 (291/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 538.6ms
# video 1/1 (292/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 545.1ms
# video 1/1 (293/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 576.3ms
# video 1/1 (294/294) C:\D drive\2023 intern\Interlocking Tiles Defect Detection GUI\test\vid-img-in\GH012496_trimmed.mp4: 800x800 1 interlocking-tiles, 1 road marking -good-, 534.0ms
# Speed: 3.0ms preprocess, 423.2ms inference, 9.1ms postprocess per image at shape (1, 3, 800, 800)

# %% [markdown]
# #### Plot results onto each frame and saves it
#
# Use 'Make Images into Video' in `processing.ipynb` afterwards to convert into video.
#
# Change `output_folder` to where the frames should be stored.

# %%
from PIL import Image
import numpy as np

output_folder = "C:/D drive/2023 intern/Interlocking Tiles Defect Detection GUI/test/predict_track"

def count_to_string(count):
    l = 8
    return "0"*(l-len(str(count))) + str(count)

count = 0
# Process results list
for result in results:
    print(result.names)
    boxes = result.boxes.cls  # Boxes object for bbox outputs
    boxes = result.boxes.conf  # Boxes object for bbox outputs
    print(boxes)
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs

    array = result.plot()
    array = array[:,:, ::-1]
    img = Image.fromarray(array)
    # img.show()

    img.save(f"{output_folder}/frame{count_to_string(count)}.jpg")

    count += 1
# Out:
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7896, 0.7372, 0.6373])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7215, 0.6924, 0.6564])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7352, 0.6949, 0.6600])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7702, 0.6541, 0.7173])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6430, 0.6510, 0.7285])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6707, 0.6230, 0.6949])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5694, 0.6307, 0.7294])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5233, 0.6279, 0.7617])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5900, 0.5965, 0.7744])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7118, 0.5951, 0.7764])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7203, 0.6190, 0.7547])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7486, 0.6538, 0.7855])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5510, 0.6259, 0.8108])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6239, 0.6094, 0.8099])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6605, 0.5864, 0.7998])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4419, 0.5889, 0.8294])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6094, 0.4990, 0.8248])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3125, 0.5129, 0.8034])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3575, 0.5537, 0.7984])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5388, 0.5339, 0.8204])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5475, 0.5258, 0.8389])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5205, 0.5059, 0.7736])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5721, 0.5871, 0.7488])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5485, 0.5372, 0.6239])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5367, 0.6437, 0.5848])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6302, 0.5580, 0.3388])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5275, 0.6446])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5187, 0.5958])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6829, 0.5962])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6034, 0.6322])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7410, 0.6870])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5674, 0.7036])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5442, 0.7435])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6859, 0.7641])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6491, 0.7378, 0.6806])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7018, 0.7996, 0.5555])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6161, 0.7231, 0.8569])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7982, 0.7571, 0.8030])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8127, 0.7532, 0.8184])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7492, 0.7506, 0.7262])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7911, 0.7541, 0.8374])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7556, 0.7369, 0.8605])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6164, 0.7464, 0.8540])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7685, 0.7043, 0.6042])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6751, 0.7830, 0.5586])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6819, 0.7571])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7440, 0.7151])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7496, 0.6268])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7237, 0.6765])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5911, 0.5485])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5238, 0.5064])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4066, 0.6283])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5344, 0.5585, 0.8227])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5215, 0.6491, 0.8839])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6528, 0.6207, 0.8518])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6137, 0.6508, 0.8692])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6145, 0.6699, 0.8859])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5923, 0.5657, 0.8436])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6624, 0.5856, 0.8517])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5789, 0.4849, 0.8401])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6568, 0.5290, 0.8298])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6152, 0.4597, 0.7891])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6499, 0.4526, 0.8318])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5301, 0.5467, 0.8204])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6739, 0.5889, 0.8366])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6168, 0.5652, 0.8434])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7347, 0.6939, 0.8475])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5234, 0.5858, 0.8428])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4211, 0.6692, 0.8235])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6349, 0.7330, 0.8466])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4685, 0.6657, 0.8239])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6305, 0.7182, 0.8179])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5874, 0.7850, 0.8201])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5858, 0.7101, 0.8366])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5649, 0.6904, 0.7982])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4982, 0.7878, 0.8386])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6343, 0.8122, 0.8027])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5910, 0.7614, 0.7827])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5263, 0.7445, 0.7628])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6902, 0.7504, 0.8073])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5422, 0.7751, 0.8052])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6303, 0.7261, 0.7966])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6762, 0.7197, 0.8022])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6215, 0.7130, 0.7928])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5738, 0.7269, 0.8045])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5446, 0.7122, 0.8144])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5913, 0.7723, 0.7934])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6065, 0.7867, 0.8119])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6608, 0.7601, 0.8201])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6355, 0.7561, 0.7971])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5635, 0.8059, 0.7767])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5379, 0.7694, 0.7785])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7997, 0.7945, 0.8143])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5889, 0.7794, 0.8118])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4687, 0.7799, 0.7951])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7976, 0.8476, 0.7960])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8405, 0.8254, 0.8148])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8349, 0.7098, 0.7873])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5865, 0.7268, 0.8189])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6998, 0.7688, 0.8422])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6624, 0.8160, 0.8406])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8088, 0.7733, 0.8058])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5691, 0.7284, 0.7888])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5329, 0.7707, 0.8408])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7657, 0.7671, 0.7788])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8322, 0.8033, 0.7448])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7843, 0.7305, 0.7556])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8089, 0.7864, 0.8384])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8113, 0.8053, 0.8557])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7167, 0.7581, 0.8526])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5712, 0.6744, 0.8048])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6303, 0.6709, 0.8257])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4934, 0.6828, 0.8032])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6687, 0.6990, 0.8135])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8115, 0.7024, 0.7631])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8252, 0.7399, 0.7978])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8157, 0.7239, 0.7084])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7821, 0.7181, 0.7205])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7586, 0.7125, 0.7900])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7771, 0.7330, 0.7337])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7675, 0.7734, 0.6674])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7523, 0.7894, 0.6207])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7407, 0.7988, 0.7430])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7206, 0.7770, 0.7569])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6691, 0.7612, 0.7842])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6850, 0.7807, 0.6641])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7098, 0.7898, 0.6389])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7636, 0.7918, 0.5485])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6893, 0.7553, 0.5636])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6449, 0.7318, 0.5718])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7521, 0.7442, 0.6191])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7806, 0.7550, 0.6186])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7872, 0.7636, 0.6751])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7929, 0.7194, 0.6963])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7726, 0.6924, 0.6033])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7513, 0.7006, 0.7553])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7132, 0.6856, 0.7810])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7187, 0.4169, 0.7556, 0.7432])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3389, 0.7664, 0.6974, 0.5925])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8240, 0.6927, 0.3431])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7788, 0.7182, 0.5145])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7866, 0.6841, 0.6471])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7457, 0.6118, 0.6475, 0.8351])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7472, 0.6027, 0.5829, 0.7985])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7694, 0.5995, 0.4551, 0.7739])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7732, 0.6960, 0.7936])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7839, 0.7125, 0.7936])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7819, 0.6840, 0.7459])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7955, 0.6836, 0.6939])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7967, 0.6686, 0.6006])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7683, 0.6825, 0.4579])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7602, 0.6832])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7845, 0.6373])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7578, 0.6830])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8009, 0.6938])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7876, 0.7226])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7982, 0.6980])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7682, 0.6656])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7699, 0.6511])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7716, 0.7294])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7843, 0.6750])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7697, 0.7152])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7552, 0.6891])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7447, 0.7549])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7497, 0.7808])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7682, 0.7686])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7422, 0.8145])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7134, 0.8083])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7691, 0.7711])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7732, 0.7420])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7634, 0.7134])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7721, 0.5403])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7517, 0.5352])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7508, 0.6135])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7618, 0.5662])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7698, 0.5656])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8106, 0.6426])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8043, 0.6088])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7874, 0.5957])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7862, 0.4887])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7998, 0.5443])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7903, 0.5474])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7904, 0.7011])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7813, 0.6614])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7686, 0.7278])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7562, 0.7229])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7594, 0.7091])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7560, 0.7015])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7871, 0.6599])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7423, 0.7057])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7735, 0.7433])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7746, 0.7080])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7563, 0.6852])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7420, 0.7373])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7589, 0.6940])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7685, 0.6964])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7373, 0.6508])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6281, 0.6874])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5436, 0.5860])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5812, 0.5015])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5367, 0.5250])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5268, 0.5221])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4958, 0.5480])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5869, 0.5340])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5855, 0.5652])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6045, 0.6096])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5657, 0.6022])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6665, 0.5735])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6441, 0.5151])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6758, 0.6432])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7202, 0.7132])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7117, 0.7115])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6664, 0.6810])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7167, 0.6875])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7364, 0.6735])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7392, 0.7037])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7328, 0.6898])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7412, 0.6849])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7024, 0.7184])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7474, 0.7213])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7493, 0.7058])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7385, 0.6564])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7575, 0.6750])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7830, 0.6412])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7790, 0.6226])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7225, 0.6609])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7131, 0.6521])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7581, 0.6898])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7552, 0.7201])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7120, 0.6722])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7115, 0.6754])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7324, 0.6772, 0.5632])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7383, 0.6944, 0.4761])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7074, 0.6911, 0.4519])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6551, 0.6399])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6690, 0.6267])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6718, 0.6317])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6247, 0.6678])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5959, 0.6614])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5617, 0.6767])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5726, 0.6417])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5749, 0.5653])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5732, 0.5796])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5203, 0.5372])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5138, 0.4994])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5230, 0.4676])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5946, 0.5865])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6340, 0.5844])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6144, 0.5466])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6124, 0.5356])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5991, 0.6287, 0.5294])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5811, 0.6722, 0.7192])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5782, 0.6286, 0.7425, 0.6439])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5394, 0.5876, 0.7635, 0.6956])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6142, 0.5494, 0.6709, 0.7862])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5129, 0.4051, 0.6379])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4860, 0.6913])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5081, 0.8021])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4099, 0.7922])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4147, 0.7967])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4580, 0.8004, 0.5467])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4745, 0.7949, 0.5394])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4249, 0.8160, 0.4641])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6736, 0.8134, 0.3687])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6625, 0.8208, 0.3154])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7225, 0.8173, 0.5355])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7508, 0.8270, 0.4104])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6786, 0.8314, 0.3433])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7078, 0.7999, 0.4303, 0.6892])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7304, 0.8080, 0.3635, 0.5169])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6795, 0.7635, 0.4025, 0.6934])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6461, 0.7800, 0.3586, 0.7349])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5251, 0.7979, 0.5054, 0.7236])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4679, 0.7421, 0.3893, 0.6587])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3903, 0.6847, 0.3757, 0.6457])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6611, 0.7185, 0.4891, 0.7272])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6968, 0.7082, 0.3836, 0.7605])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8135, 0.4827, 0.5359])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7761, 0.4314, 0.6463])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7932, 0.3042, 0.5118])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.7460, 0.5695])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8417, 0.4747])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.8210])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5400])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4613])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3691])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5348, 0.5233])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3376, 0.4304])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.3479, 0.4947])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4568, 0.5583])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5958, 0.5447])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.5641, 0.5503])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.4304, 0.5895])
# {0: 'asphalts', 1: 'interlocking-tiles', 2: 'manhole', 3: 'repair-tiles', 4: 'road marking -fade-', 5: 'road marking -good-'}
# tensor([0.6490, 0.5467])

# %% [markdown]
# ### Create images to compare original photo and predicted photo
#
# Produces image to compare original and predicted photos side-by-side.
#
# Change `output_path`, `original_image_path`, or `predicted_image_path` to paths of choice.

# %%
import cv2
import numpy as np

original_image_path = 'test_images/IMG_9402.JPG'
predicted_image_path = 'test_images/predict/IMG_9402.JPG'
output_path = 'output/predicts/new/IMG_9402.jpg'

original_img = cv2.imread(original_image_path)
predicted_img = cv2.imread(predicted_image_path)

image = cv2.imread(original_image_path)
h, w, channels = image.shape
if w > h:
    og_img = cv2.resize(original_img, (800, 800))
    predict_img = cv2.resize(predicted_img, (800, 800))
else:
    og_img = cv2.resize(original_img, (800, 800))
    predict_img = cv2.resize(predicted_img, (800, 800))

# Stacking the original image with the predicted image
result = np.hstack((og_img, predict_img))
# cv2.imshow('Result', result)
# cv2.waitKey(0)

cv2.imwrite(output_path, result)
